# %% [markdown]
# # 🏃‍♂️ Run Noisy Student
# Questo notebook permette di lanciare comodamente il training e l'evaluation per il Noisy Student direttamente dalle celle.

# %% [markdown]
# ## 1. Train

# %%
# !python train.py
# Out:
# wandb: Currently logged in as: pagliarellomatteo (pagliarellomatteo-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: setting up run 73dvswek
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in d:\Roba da D\Poli\ML Vision\speech-emotion-recognition-25\NoisyStudent_train\wandb\run-20260508_010913-73dvswek
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run noisy_student_CRNN_BiLSTM_20260508_020913
# wandb:  View project at https://wandb.ai/pagliarellomatteo-politecnico-di-torino/speech-emotion-recognition
# wandb:  View run at https://wandb.ai/pagliarellomatteo-politecnico-di-torino/speech-emotion-recognition/runs/73dvswek
# ...

# %% [markdown]
# ## 2. Evaluate

# %%
# !python eval.py
# Out:
# ...
# 🎓 NOISY STUDENT / DOMAIN ADAPTATION EVALUATION 🎓
# ...
#
# Loading IEMOCAP Session 5 (Unseen Test Set)...
# ✅ Caricate 5531 etichette
# 🔍 Raccogliendo campioni audio...
# ✅ Raccolti 731 campioni audio validi
#    - Solo campioni improvvisati
#    - Emozioni: ['neutral', 'happy', 'sad', 'angry', 'happy']
# 📊 Statistiche del dataset IEMOCAP:
#
# ...
# 📊 ANALISI IEMOCAP EVALUATION SET
# ...
#
# 🔹 SAMPLES TOTALI: 731
# 🔹 SESSIONI: ['5']
# 🔹 SPEAKER UNICI (session, gender): 2
#    Elenco: [('5', 'F'), ('5', 'M')]
# 🔹 IMPROVVISAZIONI UNICHE: 8
#    Elenco: ['01', '02', '03', '04', '05', '06', '07', '08']
#
# 👥 SPEAKER INDEPENDENCE (per verificare leakage):
#    - Sessione 5: (Ses5, F), (Ses5, M)
#
# 🎭 DISTRIBUZIONE EMOZIONI:
#    - Angry     :   31 (  4.2%)
#    - Happy     :  280 ( 38.3%) ███████
#    - Neutral   :  287 ( 39.3%) ███████
#    - Sad       :  133 ( 18.2%) ███
#
# 📋 DISTRIBUZIONE CAMPIONI PER SESSIONE:
#    - Sessione 5:  731 (100.0%) ████████████████████
#       └─ Angry     :  31 (  4.2%)
# ...
